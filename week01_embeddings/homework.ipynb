# %% [markdown]
# ## Homework: Multilingual Embedding-based Machine Translation (7 points)

# %% [markdown]
# **In this homework** **<font color='red'>YOU</font>** will make machine translation system without using parallel corpora, alignment, attention, 100500 depth super-cool recurrent neural network and all that kind superstuff.
#
# But even without parallel corpora this system can be good enough (hopefully).
#
# For our system we choose two kindred Slavic languages: Ukrainian and Russian.

# %% [markdown]
# ### Feel the difference!
#
# (_синій кіт_ vs. _синій кит_)

# %% [markdown]
# ![blue_cat_blue_whale.png](https://github.com/yandexdataschool/nlp_course/raw/master/resources/blue_cat_blue_whale.png)

# %% [markdown]
# ### Fragment of the Swadesh list for some slavic languages
#
# The Swadesh list is a lexicostatistical stuff. It's named after American linguist Morris Swadesh and contains basic lexis. This list are used to define subgroupings of languages, its relatedness.
#
# So we can see some kind of word invariance for different Slavic languages.
#
#
# | Russian         | Belorussian              | Ukrainian               | Polish             | Czech                         | Bulgarian            |
# |-----------------|--------------------------|-------------------------|--------------------|-------------------------------|-----------------------|
# | женщина         | жанчына, кабета, баба    | жінка                   | kobieta            | žena                          | жена                  |
# | мужчина         | мужчына                  | чоловік, мужчина        | mężczyzna          | muž                           | мъж                   |
# | человек         | чалавек                  | людина, чоловік         | człowiek           | člověk                        | човек                 |
# | ребёнок, дитя   | дзіця, дзіцёнак, немаўля | дитина, дитя            | dziecko            | dítě                          | дете                  |
# | жена            | жонка                    | дружина, жінка          | żona               | žena, manželka, choť          | съпруга, жена         |
# | муж             | муж, гаспадар            | чоловiк, муж            | mąż                | muž, manžel, choť             | съпруг, мъж           |
# | мать, мама      | маці, матка              | мати, матір, неня, мама | matka              | matka, máma, 'стар.' mateř    | майка                 |
# | отец, тятя      | бацька, тата             | батько, тато, татусь    | ojciec             | otec                          | баща, татко           |
# | много           | шмат, багата             | багато                  | wiele              | mnoho, hodně                  | много                 |
# | несколько       | некалькі, колькі         | декілька, кілька        | kilka              | několik, pár, trocha          | няколко               |
# | другой, иной    | іншы                     | інший                   | inny               | druhý, jiný                   | друг                  |
# | зверь, животное | жывёла, звер, істота     | тварина, звір           | zwierzę            | zvíře                         | животно               |
# | рыба            | рыба                     | риба                    | ryba               | ryba                          | риба                  |
# | птица           | птушка                   | птах, птиця             | ptak               | pták                          | птица                 |
# | собака, пёс     | сабака                   | собака, пес             | pies               | pes                           | куче, пес             |
# | вошь            | вош                      | воша                    | wesz               | veš                           | въшка                 |
# | змея, гад       | змяя                     | змія, гад               | wąż                | had                           | змия                  |
# | червь, червяк   | чарвяк                   | хробак, черв'як         | robak              | červ                          | червей                |
# | дерево          | дрэва                    | дерево                  | drzewo             | strom, dřevo                  | дърво                 |
# | лес             | лес                      | ліс                     | las                | les                           | гора, лес             |
# | палка           | кій, палка               | палиця                  | patyk, pręt, pałka | hůl, klacek, prut, kůl, pálka | палка, пръчка, бастун |

# %% [markdown]
# But the context distribution of these languages demonstrates even more invariance. And we can use this fact for our for our purposes.

# %% [markdown]
# ## Data

# %%
# %pip install gensim scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (4.3.3)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp39-cp39-macosx_12_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from gensim) (7.0.4)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: wrapt in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Downloading scikit_learn-1.5.2-cp39-cp39-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from gensim.models import KeyedVectors

# %% [markdown]
# Download embeddings here:
# * [cc.uk.300.vec.zip](https://yadi.sk/d/9CAeNsJiInoyUA)
# * [cc.ru.300.vec.zip](https://yadi.sk/d/3yG0-M4M8fypeQ)

# %% [markdown]
# Load embeddings for ukrainian and russian.

# %%
uk_emb = KeyedVectors.load_word2vec_format("cc.uk.300.vec")

# %%
ru_emb = KeyedVectors.load_word2vec_format("cc.ru.300.vec")

# %%
ru_emb.most_similar([ru_emb["август"]], topn=10)
# Out:
# [('август', 1.0),
#  ('июль', 0.9383152723312378),
#  ('сентябрь', 0.9240028262138367),
#  ('июнь', 0.9222574830055237),
#  ('октябрь', 0.9095539450645447),
#  ('ноябрь', 0.8930036425590515),
#  ('апрель', 0.8729087114334106),
#  ('декабрь', 0.8652557730674744),
#  ('март', 0.8545796275138855),
#  ('февраль', 0.8401415944099426)]

# %%
uk_emb.most_similar([uk_emb["серпень"]])
# Out:
# [('серпень', 0.9999998807907104),
#  ('липень', 0.9096440076828003),
#  ('вересень', 0.9016969203948975),
#  ('червень', 0.8992519974708557),
#  ('жовтень', 0.8810409307479858),
#  ('листопад', 0.8787633776664734),
#  ('квітень', 0.8592805862426758),
#  ('грудень', 0.8586863279342651),
#  ('травень', 0.840811014175415),
#  ('лютий', 0.8256431221961975)]

# %%
ru_emb.most_similar([uk_emb["серпень"]])
# Out:
# [('Недопустимость', 0.24435284733772278),
#  ('конструктивность', 0.23293080925941467),
#  ('офор', 0.23256802558898926),
#  ('deteydlya', 0.230317160487175),
#  ('пресечении', 0.22632381319999695),
#  ('одностороннего', 0.22608886659145355),
#  ('подход', 0.2230587750673294),
#  ('иболее', 0.22003725171089172),
#  ('2015Александр', 0.21872763335704803),
#  ('конструктивен', 0.21796567738056183)]

# %% [markdown]
# Load small dictionaries for correspoinding words pairs as trainset and testset.

# %%
def load_word_pairs(filename):
    uk_ru_pairs = []
    uk_vectors = []
    ru_vectors = []
    with open(filename, "r") as inpf:
        for line in inpf:
            uk, ru = line.rstrip().split("\t")
            if uk not in uk_emb or ru not in ru_emb:
                continue
            uk_ru_pairs.append((uk, ru))
            uk_vectors.append(uk_emb[uk])
            ru_vectors.append(ru_emb[ru])
    return uk_ru_pairs, np.array(uk_vectors), np.array(ru_vectors)

# %%
uk_ru_train, X_train, Y_train = load_word_pairs("ukr_rus.train.txt")

# %%
uk_ru_test, X_test, Y_test = load_word_pairs("ukr_rus.test.txt")

# %% [markdown]
# ## Embedding space mapping

# %% [markdown]
# Let $x_i \in \mathrm{R}^d$ be the distributed representation of word $i$ in the source language, and $y_i \in \mathrm{R}^d$ is the vector representation of its translation. Our purpose is to learn such linear transform $W$ that minimizes euclidian distance between $Wx_i$ and $y_i$ for some subset of word embeddings. Thus we can formulate so-called Procrustes problem:
#
# $$W^*= \arg\min_W \sum_{i=1}^n||Wx_i - y_i||_2$$
# or
# $$W^*= \arg\min_W ||WX - Y||_F$$
#
# where $||*||_F$ - Frobenius norm.
#
# In Greek mythology, Procrustes or "the stretcher" was a rogue smith and bandit from Attica who attacked people by stretching them or cutting off their legs, so as to force them to fit the size of an iron bed. We make same bad things with source embedding space. Our Procrustean bed is target embedding space.

# %% [markdown]
# ![embedding_mapping.png](https://github.com/yandexdataschool/nlp_course/raw/master/resources/embedding_mapping.png)

# %% [markdown]
# ![procrustes.png](https://github.com/yandexdataschool/nlp_course/raw/master/resources/procrustes.png)

# %% [markdown]
# But wait...$W^*= \arg\min_W \sum_{i=1}^n||Wx_i - y_i||_2$ looks like simple multiple linear regression (without intercept fit). So let's code.

# %%
from sklearn.linear_model import LinearRegression

# YOUR CODE HERE
mapping = LinearRegression().fit(X_train, Y_train)

# %% [markdown]
# Let's take a look at neigbours of the vector of word _"серпень"_ (_"август"_ in Russian) after linear transform.

# %%
august = mapping.predict(uk_emb["серпень"].reshape(1, -1))
ru_emb.most_similar(august)
# Out:
# [('апрель', 0.8541591167449951),
#  ('июнь', 0.8411961793899536),
#  ('март', 0.839739978313446),
#  ('сентябрь', 0.8359213471412659),
#  ('февраль', 0.8328747153282166),
#  ('октябрь', 0.8311803936958313),
#  ('ноябрь', 0.827814519405365),
#  ('июль', 0.8236350417137146),
#  ('август', 0.8120611906051636),
#  ('декабрь', 0.8037998080253601)]

# %% [markdown]
# We can see that neighbourhood of this embedding cosists of different months, but right variant is on the ninth place.

# %% [markdown]
# As quality measure we will use precision top-1, top-5 and top-10 (for each transformed Ukrainian embedding we count how many right target pairs are found in top N nearest neighbours in Russian embedding space).

# %%
def precision(pairs, mapped_vectors, topn=1):
    """
    :args:
        pairs = list of right word pairs [(uk_word_0, ru_word_0), ...]
        mapped_vectors = list of embeddings after mapping from source embedding space to destination embedding space
        topn = the number of nearest neighbours in destination embedding space to choose from
    :returns:
        precision_val, float number, total number of words for those we can find right translation at top K.
    """
    assert len(pairs) == len(mapped_vectors)
    num_matches = 0
    for i, (_, ru) in enumerate(pairs):
        # YOUR CODE HERE
        most_similar_words = [x[0] for x in ru_emb.most_similar(mapped_vectors[i], topn=topn)]
        if ru in most_similar_words:
            num_matches += 1
        
    precision_val = num_matches / len(pairs)
    return precision_val

# %%
assert precision([("серпень", "август")], august, topn=5) == 0.0
assert precision([("серпень", "август")], august, topn=9) == 1.0
assert precision([("серпень", "август")], august, topn=10) == 1.0
# Out:
# [('апрель', 0.8541591167449951), ('июнь', 0.8411961793899536), ('март', 0.839739978313446), ('сентябрь', 0.8359213471412659), ('февраль', 0.8328747153282166)]
# ['апрель', 'июнь', 'март', 'сентябрь', 'февраль']
# [('апрель', 0.8541591167449951), ('июнь', 0.8411961793899536), ('март', 0.839739978313446), ('сентябрь', 0.8359213471412659), ('февраль', 0.8328747153282166), ('октябрь', 0.8311803936958313), ('ноябрь', 0.827814519405365), ('июль', 0.8236350417137146), ('август', 0.8120611906051636)]
# ['апрель', 'июнь', 'март', 'сентябрь', 'февраль', 'октябрь', 'ноябрь', 'июль', 'август']
# [('апрель', 0.8541591167449951), ('июнь', 0.8411961793899536), ('март', 0.839739978313446), ('сентябрь', 0.8359213471412659), ('февраль', 0.8328747153282166), ('октябрь', 0.8311803936958313), ('ноябрь', 0.827814519405365), ('июль', 0.8236350417137146), ('август', 0.8120611906051636), ('декабрь', 0.8037998080253601)]
# ['апрель', 'июнь', 'март', 'сентябрь', 'февраль', 'октябрь', 'ноябрь', 'июль', 'август', 'декабрь']

# %%
assert precision(uk_ru_test, X_test) == 0.0
assert precision(uk_ru_test, Y_test) == 1.0
# Out:
# [('Макетные', 0.27161112427711487)]
# ['Макетные']
# [('почтаВаш', 0.2344067096710205)]
# ['почтаВаш']
# [('отсека', 0.2201579511165619)]
# ['отсека']
# [('пролитие', 0.27322709560394287)]
# ['пролитие']
# [('плаву', 0.3098427951335907)]
# ['плаву']
# [('целину', 0.2618544101715088)]
# ['целину']
# [('коль', 0.23096901178359985)]
# ['коль']
# [('Распоряжением', 0.27466651797294617)]
# ['Распоряжением']
# [('мозаикаТовары', 0.3128543198108673)]
# ['мозаикаТовары']
# [('храброй', 0.22299253940582275)]
# ['храброй']
# [('сельдерея', 0.2619952857494354)]
# ['сельдерея']
# [('витие', 0.23209522664546967)]
# ['витие']
# [('Вибрация', 0.26068076491355896)]
# ['Вибрация']
# [('генезисе', 0.21889422833919525)]
# ['генезисе']
# [('Подшлемник', 0.2614244520664215)]
# ['Подшлемник']
# [('изволению', 0.2342526912689209)]
# ['изволению']
# [('произведен', 0.28537413477897644)]
# ['произведен']
# [('писак', 0.23372133076190948)]
# ['писак']
# [('рычаге', 0.2744354009628296)]
# ['рычаге']
# [('выпуска', 0.27132266759872437)]
# ['выпуска']
# [('BERLINGO', 0.2467462569475174)]
# ['BERLINGO']
# [('Викитека', 0.23315688967704773)]
# ['Викитека']
# [('Указом', 0.23695695400238037)]
# ['Указом']
# [('Беспечный', 0.24735024571418762)]
# ['Беспечный']
# [('кгКоличество', 0.2523854672908783)]
# ['кгКоличество']
# [('Беспечный', 0.2691522538661957)]
# ['Беспечный']
# [('запретил', 0.23057885468006134)]
# ['запретил']
# [('Легкий', 0.26145052909851074)]
# ['Легкий']
# [('цензуре', 0.2362922877073288)]
# ['цензуре']
# [('уплате', 0.26725396513938904)]
# ['уплате']
# [('изобретателя', 0.24587543308734894)]
# ['изобретателя']
# [('далека', 0.2556597590446472)]
# ['далека']
# [('Китчен', 0.24504154920578003)]
# ['Китчен']
# [('Выйду', 0.2826556861400604)]
# ['Выйду']
# [('полетах', 0.23357176780700684)]
# ['полетах']
# [('начата', 0.21364057064056396)]
# ['начата']
# [('воспитан', 0.26462751626968384)]
# ['воспитан']
# [('скошен', 0.22097556293010712)]
# ['скошен']
# [('управление', 0.26333415508270264)]
# ['управление']
# [('чтимый', 0.2710339426994324)]
# ['чтимый']
# [('сформирование', 0.2543758749961853)]
# ['сформирование']
# [('Яндекс.МаркетеPrice', 0.24000553786754608)]
# ['Яндекс.МаркетеPrice']
# [('Печать', 0.32103994488716125)]
# ['Печать']
# [('усомнившись', 0.2381908893585205)]
# ['усомнившись']
# [('решены', 0.2276037037372589)]
# ['решены']
# [('неправде', 0.24382910132408142)]
# ['неправде']
# [('врачейКак', 0.2542579472064972)]
# ['врачейКак']
# [('преодолением', 0.26914918422698975)]
# ['преодолением']
# [('вмятина', 0.2416483610868454)]
# ['вмятина']
# [('выносу', 0.2562236189842224)]
# ['выносу']
# [('универсиаде', 0.21945565938949585)]
# ['универсиаде']
# [('склеиваем', 0.25444379448890686)]
# ['склеиваем']
# [('Флебология', 0.27157163619995117)]
# ['Флебология']
# [('Жовтневый', 0.23581011593341827)]
# ['Жовтневый']
# [('deteydlya', 0.26905331015586853)]
# ['deteydlya']
# [('конструктивному', 0.24359984695911407)]
# ['конструктивному']
# [('2Режим', 0.2443435788154602)]
# ['2Режим']
# [('перекосы', 0.26782363653182983)]
# ['перекосы']
# [('потерпит', 0.2782433331012726)]
# ['потерпит']
# [('микрофонных', 0.2187579870223999)]
# ['микрофонных']
# [('расходилась', 0.235557422041893)]
# ['расходилась']
# [('gray', 0.25221702456474304)]
# ['gray']
# [('посадки', 0.2926010191440582)]
# ['посадки']
# [('посадки', 0.2926010191440582)]
# ['посадки']
# [('наклонена', 0.2719886302947998)]
# ['наклонена']
# [('пойме', 0.25204387307167053)]
# ['пойме']
# [('семейственности', 0.2008954882621765)]
# ['семейственности']
# [('трамбовки', 0.22322247922420502)]
# ['трамбовки']
# [('Йосеф', 0.27935171127319336)]
# ['Йосеф']
# [('руб.Продажа', 0.2485625445842743)]
# ['руб.Продажа']
# [('руб.Продажа', 0.2485625445842743)]
# ['руб.Продажа']
# [('Aquaris', 0.25880053639411926)]
# ['Aquaris']
# [('Волгоградский', 0.2666042149066925)]
# ['Волгоградский']
# [('̯', 0.27609071135520935)]
# ['̯']
# [('Обсуждение', 0.2931007444858551)]
# ['Обсуждение']
# [('е39', 0.26487207412719727)]
# ['е39']
# [('рывки', 0.2483459860086441)]
# ['рывки']
# [('фамилиях', 0.23164816200733185)]
# ['фамилиях']
# [('насущного', 0.23740752041339874)]
# ['насущного']
# [('Айрис-Пресс', 0.2687286138534546)]
# ['Айрис-Пресс']
# [('скоростях', 0.2686458230018616)]
# ['скоростях']
# [('маркая', 0.19894444942474365)]
# ['маркая']
# [('руб.Картридж', 0.267361044883728)]
# ['руб.Картридж']
# [('обеспечивал', 0.2483326643705368)]
# ['обеспечивал']
# [('выродился', 0.28018492460250854)]
# ['выродился']
# [('рожд', 0.24520377814769745)]
# ['рожд']
# [('пята', 0.240156888961792)]
# ['пята']
# [('RACO', 0.24152128398418427)]
# ['RACO']
# [('Заседание', 0.27352431416511536)]
# ['Заседание']
# [('испытаниях', 0.2733689248561859)]
# ['испытаниях']
# [('поучение', 0.23741377890110016)]
# ['поучение']
# [('Посадка', 0.25513598322868347)]
# ['Посадка']
# [('планируемая', 0.24887146055698395)]
# ['планируемая']
# [('оратора', 0.2571758031845093)]
# ['оратора']
# [('Ксенией', 0.2622867226600647)]
# ['Ксенией']
# [('Летал', 0.2782822251319885)]
# ['Летал']
# [('полеты', 0.2416059970855713)]
# ['полеты']
# [('катапультирования', 0.28061845898628235)]
# ['катапультирования']
# [('стяжках', 0.28404682874679565)]
# ['стяжках']
# [('картирование', 0.26437652111053467)]
# ['картирование']
# [('г.Распродажа', 0.23896026611328125)]
# ['г.Распродажа']
# [('проверен', 0.24329440295696259)]
# ['проверен']
# [('Обсуждение', 0.2739129960536957)]
# ['Обсуждение']
# [('Корреспондент.net.', 0.2812918424606323)]
# ['Корреспондент.net.']
# [('Мажилис', 0.2741776704788208)]
# ['Мажилис']
# [('чертах', 0.23423424363136292)]
# ['чертах']
# [('manus', 0.23640358448028564)]
# ['manus']
# [('Утверждён', 0.25136762857437134)]
# ['Утверждён']
# [('Pretenderrs', 0.2161037027835846)]
# ['Pretenderrs']
# [('холодил', 0.2523469924926758)]
# ['холодил']
# [('компанияСтрахованиеСтрахование', 0.254620224237442)]
# ['компанияСтрахованиеСтрахование']
# [('проверим', 0.21996083855628967)]
# ['проверим']
# [('консалтингПерсональный', 0.257968008518219)]
# ['консалтингПерсональный']
# [('консалтингПерсональный', 0.257968008518219)]
# ['консалтингПерсональный']
# [('Ташкентского', 0.2589890956878662)]
# ['Ташкентского']
# [('Akita', 0.22391213476657867)]
# ['Akita']
# [('полосатый', 0.24091710150241852)]
# ['полосатый']
# [('пилотирование', 0.2788923978805542)]
# ['пилотирование']
# [('отбросами', 0.25769636034965515)]
# ['отбросами']
# [('достоинстве', 0.26485440135002136)]
# ['достоинстве']
# [('достоинстве', 0.26485440135002136)]
# ['достоинстве']
# [('падении', 0.2602286636829376)]
# ['падении']
# [('беспечный', 0.27059730887413025)]
# ['беспечный']
# [('построениях', 0.21115830540657043)]
# ['построениях']
# [('несла', 0.2451278269290924)]
# ['несла']
# [('deevrod', 0.29256150126457214)]
# ['deevrod']
# [('свойстве', 0.24315376579761505)]
# ['свойстве']
# [('Утверждён', 0.26390111446380615)]
# ['Утверждён']
# [('Утверждён', 0.26390111446380615)]
# ['Утверждён']
# [('наклонного', 0.24107159674167633)]
# ['наклонного']
# [('объязательно', 0.24344520270824432)]
# ['объязательно']
# [('движителя', 0.24552080035209656)]
# ['движителя']
# [('патентоспособности', 0.2563420236110687)]
# ['патентоспособности']
# [('Смелость', 0.20083774626255035)]
# ['Смелость']
# [('рад', 0.22975604236125946)]
# ['рад']
# [('бабушкина', 0.23721791803836823)]
# ['бабушкина']
# [('Переходная', 0.2376118153333664)]
# ['Переходная']
# [('блистера', 0.23125551640987396)]
# ['блистера']
# [('модератора', 0.27180421352386475)]
# ['модератора']
# [('уздечке', 0.2492685317993164)]
# ['уздечке']
# [('подвергнута', 0.2739410102367401)]
# ['подвергнута']
# [('ретрансляция', 0.2552396357059479)]
# ['ретрансляция']
# [('черкесских', 0.22365973889827728)]
# ['черкесских']
# [('орошает', 0.23734839260578156)]
# ['орошает']
# [('орошает', 0.23734839260578156)]
# ['орошает']
# [('адресована', 0.22906959056854248)]
# ['адресована']
# [('способствующую', 0.23035961389541626)]
# ['способствующую']
# [('Анапского', 0.27329179644584656)]
# ['Анапского']
# [('ISR', 0.23578181862831116)]
# ['ISR']
# [('Розенбаум', 0.26118674874305725)]
# ['Розенбаум']
# [('ударилась', 0.254003643989563)]
# ['ударилась']
# [('Недопустимость', 0.27826768159866333)]
# ['Недопустимость']
# [('способствования', 0.2482539564371109)]
# ['способствования']
# [('Dingo', 0.2282484918832779)]
# ['Dingo']
# [('безотказную', 0.24989058077335358)]
# ['безотказную']
# [('орбитальная', 0.20875318348407745)]
# ['орбитальная']
# [('скоростях', 0.2826947271823883)]
# ['скоростях']
# [('лицензированию', 0.26560112833976746)]
# ['лицензированию']
# [('ремонтопригодность', 0.20875655114650726)]
# ['ремонтопригодность']
# [('объявленийАренда', 0.22819823026657104)]
# ['объявленийАренда']
# [('добровольном', 0.24657906591892242)]
# ['добровольном']
# [('литератора', 0.24263864755630493)]
# ['литератора']
# [('педагогическому', 0.28657305240631104)]
# ['педагогическому']
# [('поднимается', 0.2737390697002411)]
# ['поднимается']
# [('Эйфель', 0.26608437299728394)]
# ['Эйфель']
# [('скульптураМодель', 0.23386819660663605)]
# ['скульптураМодель']
# [('эпоху', 0.29235395789146423)]
# ['эпоху']
# [('Клятва', 0.26375696063041687)]
# ['Клятва']
# [('Ипполитович', 0.27774715423583984)]
# ['Ипполитович']
# [('удалившись', 0.24076394736766815)]
# ['удалившись']
# [('допустила', 0.2205168902873993)]
# ['допустила']
# [('приварена', 0.27865922451019287)]
# ['приварена']
# [('приварена', 0.24185219407081604)]
# ['приварена']
# [('Указом', 0.2923051118850708)]
# ['Указом']
# [('пострижен', 0.28717607259750366)]
# ['пострижен']
# [('ложемент', 0.264972060918808)]
# ['ложемент']
# [('испытана', 0.2644519805908203)]
# ['испытана']
# [('Glofiish', 0.27632248401641846)]
# ['Glofiish']
# [('привитый', 0.26591598987579346)]
# ['привитый']
# [('фокусирование', 0.26726675033569336)]
# ['фокусирование']
# [('повреждений', 0.22503775358200073)]
# ['повреждений']
# [('Списан', 0.26582100987434387)]
# ['Списан']
# [('Флебология', 0.24851712584495544)]
# ['Флебология']
# [('тейпов', 0.22193296253681183)]
# ['тейпов']
# [('Грушин', 0.3060988187789917)]
# ['Грушин']
# [('самоходным', 0.29367634654045105)]
# ['самоходным']
# [('развёрнута', 0.26621004939079285)]
# ['развёрнута']
# [('выносила', 0.2484256625175476)]
# ['выносила']
# [('параметрах', 0.2221931368112564)]
# ['параметрах']
# [('занятии', 0.27990227937698364)]
# ['занятии']
# [('чинит', 0.2733621597290039)]
# ['чинит']
# [('крепка', 0.20244421064853668)]
# ['крепка']
# [('инициировала', 0.23754800856113434)]
# ['инициировала']
# [('знакомил', 0.27360156178474426)]
# ['знакомил']
# [('y1', 0.23352742195129395)]
# ['y1']
# [('старт', 0.243864506483078)]
# ['старт']
# [('корешок', 0.29474207758903503)]
# ['корешок']
# [('завершалась', 0.3027428686618805)]
# ['завершалась']
# [('Катон', 0.290425568819046)]
# ['Катон']
# [('развернута', 0.3306276798248291)]
# ['развернута']
# [('стёрта', 0.24118539690971375)]
# ['стёрта']
# [('ершики', 0.24796533584594727)]
# ['ершики']
# [('Указом', 0.2747625708580017)]
# ['Указом']
# [('преподобные', 0.26199349761009216)]
# ['преподобные']
# [('Травник', 0.24926139414310455)]
# ['Травник']
# [('долгожитель', 0.233525812625885)]
# ['долгожитель']
# [('полете', 0.25315824151039124)]
# ['полете']
# [('отдам', 0.23237206041812897)]
# ['отдам']
# [('полету', 0.2477441281080246)]
# ['полету']
# [('травлении', 0.2607780694961548)]
# ['травлении']
# [('травлении', 0.2607780694961548)]
# ['травлении']
# [('выведению', 0.263641357421875)]
# ['выведению']
# [('добровольный', 0.2440827637910843)]
# ['добровольный']
# [('тренировке', 0.2463168054819107)]
# ['тренировке']
# [('ботанического', 0.2302045077085495)]
# ['ботанического']
# [('Ташкентского', 0.2520119547843933)]
# ['Ташкентского']
# [('Реализация', 0.25709760189056396)]
# ['Реализация']
# [('bookap.by.ru2000', 0.21497619152069092)]
# ['bookap.by.ru2000']
# [('аттестованные', 0.26520681381225586)]
# ['аттестованные']
# [('Древко', 0.25762465596199036)]
# ['Древко']
# [('Разгрузки', 0.2701474130153656)]
# ['Разгрузки']
# [('мм.Ширина', 0.27812695503234863)]
# ['мм.Ширина']
# [('.Информация', 0.2852587401866913)]
# ['.Информация']
# [('БРЭМ', 0.25958406925201416)]
# ['БРЭМ']
# [('гражд.', 0.26029226183891296)]
# ['гражд.']
# [('приспособлена', 0.24826768040657043)]
# ['приспособлена']
# [('Рудра', 0.2564646005630493)]
# ['Рудра']
# [('Гудрич', 0.2144111692905426)]
# ['Гудрич']
# [('зачатками', 0.22266605496406555)]
# ['зачатками']
# [('борт', 0.27832865715026855)]
# ['борт']
# [('порядке.', 0.23935498297214508)]
# ['порядке.']
# [('Ранен', 0.2597307562828064)]
# ['Ранен']
# [('мутагенез', 0.25409573316574097)]
# ['мутагенез']
# [('крепление', 0.24005696177482605)]
# ['крепление']
# [('Беспроводной', 0.26336315274238586)]
# ['Беспроводной']
# [('свойстве', 0.24296045303344727)]
# ['свойстве']
# [('грубиян', 0.2614257037639618)]
# ['грубиян']
# [('Заблокирован', 0.3098457455635071)]
# ['Заблокирован']
# [('направлена', 0.29633960127830505)]
# ['направлена']
# [('иссечение', 0.23621346056461334)]
# ['иссечение']
# [('полету', 0.23883478343486786)]
# ['полету']
# [('готовке', 0.24550922214984894)]
# ['готовке']
# [('F300', 0.23485158383846283)]
# ['F300']
# [('Начавшись', 0.3110400438308716)]
# ['Начавшись']
# [('Проверенное', 0.23714487254619598)]
# ['Проверенное']
# [('угощали', 0.234798863530159)]
# ['угощали']
# [('возложению', 0.2909952998161316)]
# ['возложению']
# [('Волгоградский', 0.26820436120033264)]
# ['Волгоградский']
# [('отзывчивость', 0.23152071237564087)]
# ['отзывчивость']
# [('сегодн', 0.2325970083475113)]
# ['сегодн']
# [('госиспытания', 0.2538631856441498)]
# ['госиспытания']
# [('Uniq', 0.2508549690246582)]
# ['Uniq']
# [('полежите', 0.26245206594467163)]
# ['полежите']
# [('порадуется', 0.25571855902671814)]
# ['порадуется']
# [('Сушка', 0.23235081136226654)]
# ['Сушка']
# [('сказанию', 0.2673972249031067)]
# ['сказанию']
# [('чистящий', 0.24464742839336395)]
# ['чистящий']
# [('настояла', 0.23962615430355072)]
# ['настояла']
# [('вынесена', 0.3501054346561432)]
# ['вынесена']
# [('беседа', 0.34036049246788025)]
# ['беседа']
# [('Изготовлено', 0.2213556170463562)]
# ['Изготовлено']
# [('черта', 0.2352181226015091)]
# ['черта']
# [('свая', 0.2512228488922119)]
# ['свая']
# [('наколенников', 0.25083038210868835)]
# ['наколенников']
# [('посадки', 0.25228825211524963)]
# ['посадки']
# [('Киеве', 0.25616949796676636)]
# ['Киеве']
# [('гидрофильный', 0.28095194697380066)]
# ['гидрофильный']
# [('шалит', 0.2559748589992523)]
# ['шалит']
# [('устах', 0.21893665194511414)]
# ['устах']
# [('стремлениях', 0.2799834907054901)]
# ['стремлениях']
# [('сшивание', 0.2251529097557068)]
# ['сшивание']
# [('укоренению', 0.2303314059972763)]
# ['укоренению']
# [('обретение', 0.26581358909606934)]
# ['обретение']
# [('приравнивания', 0.2578645944595337)]
# ['приравнивания']
# [('бортиком', 0.23900912702083588)]
# ['бортиком']
# [('конструктивный', 0.27367842197418213)]
# ['конструктивный']
# [('осмотр', 0.25054502487182617)]
# ['осмотр']
# [('Wanderer', 0.2729959487915039)]
# ['Wanderer']
# [('выходящей', 0.24051934480667114)]
# ['выходящей']
# [('сечет', 0.27345165610313416)]
# ['сечет']
# [('Выйдя', 0.2744399905204773)]
# ['Выйдя']
# [('ВАЛЕНТИНА', 0.22599147260189056)]
# ['ВАЛЕНТИНА']
# [('Ruberi', 0.2698935568332672)]
# ['Ruberi']
# [('полетах', 0.2421853095293045)]
# ['полетах']
# [('азов', 0.2101442962884903)]
# ['азов']
# [('Сборная', 0.22882625460624695)]
# ['Сборная']
# [('разработ', 0.2613537609577179)]
# ['разработ']
# [('валках', 0.25991708040237427)]
# ['валках']
# [('Покрой', 0.2177191525697708)]
# ['Покрой']
# [('main.jpg', 0.283073365688324)]
# ['main.jpg']
# [('18.05.2000', 0.2628512978553772)]
# ['18.05.2000']
# [('Helsing', 0.2975803315639496)]
# ['Helsing']
# [('Недопустимость', 0.24435284733772278)]
# ['Недопустимость']
# [('сатана', 0.223526269197464)]
# ['сатана']
# [('Черноярского', 0.266226589679718)]
# ['Черноярского']
# [('нрава', 0.23239529132843018)]
# ['нрава']
# [('очищению', 0.30029332637786865)]
# ['очищению']
# [('попадала', 0.26660770177841187)]
# ['попадала']
# [('производительного', 0.21030153334140778)]
# ['производительного']
# [('признаке', 0.23489953577518463)]
# ['признаке']
# [('полетах', 0.26288631558418274)]
# ['полетах']
# [('ядрах', 0.24902814626693726)]
# ['ядрах']
# [('мужчинОдежда', 0.211168110370636)]
# ['мужчинОдежда']
# [('холост', 0.24343371391296387)]
# ['холост']
# [('ИСПЫТАНИЙ', 0.228598952293396)]
# ['ИСПЫТАНИЙ']
# [('Добро', 0.24018637835979462)]
# ['Добро']
# [('оскорблениях', 0.2600650191307068)]
# ['оскорблениях']
# [('1год', 0.25562047958374023)]
# ['1год']
# [('мужчинОдежда', 0.27222827076911926)]
# ['мужчинОдежда']
# [('мудр', 0.26676997542381287)]
# ['мудр']
# [('снастях', 0.19528518617153168)]
# ['снастях']
# [('полетах', 0.27351081371307373)]
# ['полетах']
# [('жаловала', 0.24908339977264404)]
# ['жаловала']
# [('сохране', 0.2560739517211914)]
# ['сохране']
# [('потерпела', 0.28607288002967834)]
# ['потерпела']
# [('скошена', 0.24729633331298828)]
# ['скошена']
# [('выреза', 0.254109263420105)]
# ['выреза']
# [('эллипсоида', 0.2705197036266327)]
# ['эллипсоида']
# [('--Влад', 0.25865787267684937)]
# ['--Влад']
# [('bookap.by.ru2000', 0.2353459894657135)]
# ['bookap.by.ru2000']
# [('bookap.by.ru2000', 0.2353459894657135)]
# ['bookap.by.ru2000']
# [('Бандаж', 0.24470871686935425)]
# ['Бандаж']
# [('излечению', 0.23582389950752258)]
# ['излечению']
# [('качествах', 0.25736376643180847)]
# ['качествах']
# [('голосаВаш', 0.26267334818840027)]
# ['голосаВаш']
# [('поражается', 0.23304583132266998)]
# ['поражается']
# [('неудачна', 0.2750590145587921)]
# ['неудачна']
# [('благословении', 0.24776507914066315)]
# ['благословении']
# [('11Разработчик', 0.24246647953987122)]
# ['11Разработчик']
# [('радиоуправляемым', 0.2561655640602112)]
# ['радиоуправляемым']
# [('средстваЗащита', 0.2687516510486603)]
# ['средстваЗащита']
# [('осуществлено', 0.24950219690799713)]
# ['осуществлено']
# [('студеной', 0.2552022933959961)]
# ['студеной']
# [('Option', 0.25357508659362793)]
# ['Option']
# [('deteydlya', 0.2686212956905365)]
# ['deteydlya']
# [('будеш', 0.21541674435138702)]
# ['будеш']
# [('Ахилл', 0.29141372442245483)]
# ['Ахилл']
# [('Scrub', 0.25143706798553467)]
# ['Scrub']
# [('Мобилизация', 0.2773677110671997)]
# ['Мобилизация']
# [('самообороне', 0.24374181032180786)]
# ['самообороне']
# [('Вегетативная', 0.2666303515434265)]
# ['Вегетативная']
# [('актуальна', 0.26853320002555847)]
# ['актуальна']
# [('планёров', 0.21736523509025574)]
# ['планёров']
# [('прополке', 0.22543787956237793)]
# ['прополке']
# [('рубке', 0.26451632380485535)]
# ['рубке']
# [('конструктивна', 0.2391722947359085)]
# ['конструктивна']
# [('конструктивна', 0.2391722947359085)]
# ['конструктивна']
# [('гиперзвуковой', 0.26995617151260376)]
# ['гиперзвуковой']
# [('Бажана', 0.23351801931858063)]
# ['Бажана']
# [('Покрой', 0.23231491446495056)]
# ['Покрой']
# [('произведён', 0.22718662023544312)]
# ['произведён']
# [('безоблачная', 0.2254560887813568)]
# ['безоблачная']
# [('Kärcher', 0.22066164016723633)]
# ['Kärcher']
# [('Solio', 0.2323702573776245)]
# ['Solio']
# [('вкладыша', 0.2277546525001526)]
# ['вкладыша']
# [('Вителлий', 0.2468973994255066)]
# ['Вителлий']
# [('млАртикул', 0.249348446726799)]
# ['млАртикул']
# [('750мм', 0.26359888911247253)]
# ['750мм']
# [('наработках', 0.25421053171157837)]
# ['наработках']
# [('дес.', 0.22622007131576538)]
# ['дес.']
# [('труженика', 0.27074816823005676)]
# ['труженика']
# [('наличиинайти', 0.2086363583803177)]
# ['наличиинайти']
# [('аспектах', 0.2008098065853119)]
# ['аспектах']
# [('запасная', 0.28431016206741333)]
# ['запасная']
# [('пята', 0.26428431272506714)]
# ['пята']
# [('обязывается', 0.3194960951805115)]
# ['обязывается']
# [('Приземление', 0.2703603506088257)]
# ['Приземление']
# [('спорящих', 0.2718171775341034)]
# ['спорящих']
# [('посадкам', 0.22841666638851166)]
# ['посадкам']
# [('посадкам', 0.22841666638851166)]
# ['посадкам']
# [('пикселяСоотношение', 0.26900699734687805)]
# ['пикселяСоотношение']
# [('эллинга', 0.24185651540756226)]
# ['эллинга']
# [('присяге', 0.2696845829486847)]
# ['присяге']
# [('присяге', 0.2696845829486847)]
# ['присяге']
# [('Усманов', 0.23764634132385254)]
# ['Усманов']
# [('ординарного', 0.24417927861213684)]
# ['ординарного']
# [('Муравский', 0.23871515691280365)]
# ['Муравский']
# [('испытаниях', 0.2762579619884491)]
# ['испытаниях']
# [('испытаниях', 0.2762579619884491)]
# ['испытаниях']
# [('дисплейный', 0.2441757768392563)]
# ['дисплейный']
# [('BeSafe', 0.2620716691017151)]
# ['BeSafe']
# [('Гонок', 0.2547893822193146)]
# ['Гонок']
# [('колея', 0.23298846185207367)]
# ['колея']
# [('12И', 0.23295795917510986)]
# ['12И']
# [('M600', 0.25862064957618713)]
# ['M600']
# [('прадед', 0.26191389560699463)]
# ['прадед']
# [('перетяжка', 0.30254554748535156)]
# ['перетяжка']
# [('либо', 1.0000001192092896)]
# ['либо']
# [('активный', 1.0000001192092896)]
# ['активный']
# [('актер', 1.0000001192092896)]
# ['актер']
# [('ж', 1.0000001192092896)]
# ['ж']
# [('собрание', 1.0)]
# ['собрание']
# [('бабушка', 1.0)]
# ['бабушка']
# [('ствол', 0.9999998807907104)]
# ['ствол']
# [('желать', 1.0)]
# ['желать']
# [('башня', 1.0000001192092896)]
# ['башня']
# [('бизнес', 1.0)]
# ['бизнес']
# [('драка', 0.9999998807907104)]
# ['драка']
# [('молния', 1.0)]
# ['молния']
# [('браться', 0.9999999403953552)]
# ['браться']
# [('домик', 1.0)]
# ['домик']
# [('строительство', 1.0)]
# ['строительство']
# [('важно', 0.9999999403953552)]
# ['важно']
# [('валить', 0.9999999403953552)]
# ['валить']
# [('груз', 1.0000001192092896)]
# ['груз']
# [('благодарность', 1.0000001192092896)]
# ['благодарность']
# [('величество', 1.0000001192092896)]
# ['величество']
# [('обед', 1.0000001192092896)]
# ['обед']
# [('вечерний', 1.0)]
# ['вечерний']
# [('выбирать', 0.9999998807907104)]
# ['выбирать']
# [('признать', 1.0)]
# ['признать']
# [('использовать', 1.0)]
# ['использовать']
# [('вынести', 1.0)]
# ['вынести']
# [('приговор', 0.9999999403953552)]
# ['приговор']
# [('выступить', 1.0)]
# ['выступить']
# [('отвести', 1.0000001192092896)]
# ['отвести']
# [('открываться', 0.9999999403953552)]
# ['открываться']
# [('отличный', 1.0)]
# ['отличный']
# [('отрезать', 0.9999999403953552)]
# ['отрезать']
# [('возраст', 1.0)]
# ['возраст']
# [('восемь', 0.9999999403953552)]
# ['восемь']
# [('пожаловать', 1.0)]
# ['пожаловать']
# [('волк', 1.0)]
# ['волк']
# [('водить', 0.9999998807907104)]
# ['водить']
# [('водитель', 0.9999999403953552)]
# ['водитель']
# [('обладать', 1.0)]
# ['обладать']
# [('уверенность', 1.0)]
# ['уверенность']
# [('учесть', 1.0)]
# ['учесть']
# [('спасти', 1.0)]
# ['спасти']
# [('вмешиваться', 1.0000001192092896)]
# ['вмешиваться']
# [('ухо', 1.0)]
# ['ухо']
# [('подъезд', 1.0000001192092896)]
# ['подъезд']
# [('газета', 0.9999998807907104)]
# ['газета']
# [('отрасль', 1.0)]
# ['отрасль']
# [('поляна', 1.0)]
# ['поляна']
# [('гений', 1.0000001192092896)]
# ['гений']
# [('проговорить', 1.0000001192092896)]
# ['проговорить']
# [('голодный', 1.0)]
# ['голодный']
# [('отель', 1.0000001192092896)]
# ['отель']
# [('готовность', 1.0)]
# ['готовность']
# [('гражданин', 1.0)]
# ['гражданин']
# [('декабрь', 1.0)]
# ['декабрь']
# [('почва', 1.0)]
# ['почва']
# [('крыша', 1.0000001192092896)]
# ['крыша']
# [('двести', 1.0000001192092896)]
# ['двести']
# [('дважды', 1.0)]
# ['дважды']
# [('где', 1.0)]
# ['где']
# [('лес', 0.9999998807907104)]
# ['лес']
# [('зеркало', 1.0)]
# ['зеркало']
# [('глядеть', 1.0)]
# ['глядеть']
# [('смотреть', 1.0)]
# ['смотреть']
# [('дивизия', 1.0)]
# ['дивизия']
# [('удивляться', 1.0)]
# ['удивляться']
# [('бриллианты', 1.0)]
# ['бриллианты']
# [('дед', 1.0000001192092896)]
# ['дед']
# [('дни', 0.9999998807907104)]
# ['дни']
# [('принести', 1.0)]
# ['принести']
# [('приносить', 1.0000001192092896)]
# ['приносить']
# [('доказать', 1.0)]
# ['доказать']
# [('позволять', 1.0000001192092896)]
# ['позволять']
# [('ко', 0.9999998807907104)]
# ['ко']
# [('допустить', 1.0)]
# ['допустить']
# [('остроты', 1.0)]
# ['остроты']
# [('остроумно', 1.0)]
# ['остроумно']
# [('дурной', 1.0)]
# ['дурной']
# [('духовный', 1.0)]
# ['духовный']
# [('экспедиция', 1.0)]
# ['экспедиция']
# [('электрический', 0.9999999403953552)]
# ['электрический']
# [('элемент', 1.0)]
# ['элемент']
# [('сцена', 1.0)]
# ['сцена']
# [('жалко', 1.0)]
# ['жалко']
# [('шутка', 0.9999998807907104)]
# ['шутка']
# [('женить', 0.9999998807907104)]
# ['женить']
# [('жизненный', 1.0)]
# ['жизненный']
# [('арестовать', 0.9999998807907104)]
# ['арестовать']
# [('обеспечить', 1.0000001192092896)]
# ['обеспечить']
# [('задавать', 1.0000001192092896)]
# ['задавать']
# [('удовольствие', 1.0000001192092896)]
# ['удовольствие']
# [('заглянуть', 1.0000001192092896)]
# ['заглянуть']
# [('закрывать', 1.0000001192092896)]
# ['закрывать']
# [('железнодорожный', 1.0)]
# ['железнодорожный']
# [('охотно', 1.0000001192092896)]
# ['охотно']
# [('предложить', 1.0)]
# ['предложить']
# [('приглашать', 1.0)]
# ['приглашать']
# [('засыпать', 1.0)]
# ['засыпать']
# [('заседание', 1.0)]
# ['заседание']
# [('успокоить', 1.0)]
# ['успокоить']
# [('задержать', 1.0)]
# ['задержать']
# [('защита', 1.0)]
# ['защита']
# [('сохраниться', 1.0000001192092896)]
# ['сохраниться']
# [('собрание', 1.0)]
# ['собрание']
# [('оружие', 0.9999999403953552)]
# ['оружие']
# [('обыкновенный', 1.0)]
# ['обыкновенный']
# [('согласный', 1.0)]
# ['согласный']
# [('сдать', 0.9999998807907104)]
# ['сдать']
# [('зимний', 1.0)]
# ['зимний']
# [('признаться', 0.9999999403953552)]
# ['признаться']
# [('сорваться', 1.0)]
# ['сорваться']
# [('вор', 1.0)]
# ['вор']
# [('изменить', 1.0)]
# ['изменить']
# [('сменить', 1.0)]
# ['сменить']
# [('найти', 1.0)]
# ['найти']
# [('знание', 1.0)]
# ['знание']
# [('уничтожить', 1.0)]
# ['уничтожить']
# [('вновь', 1.0000001192092896)]
# ['вновь']
# [('образ', 1.0)]
# ['образ']
# [('составить', 1.0)]
# ['составить']
# [('составлять', 0.9999998807907104)]
# ['составлять']
# [('сделаться', 0.9999998807907104)]
# ['сделаться']
# [('разобраться', 1.0000001192092896)]
# ['разобраться']
# [('удобный', 1.0)]
# ['удобный']
# [('наверно', 1.0000001192092896)]
# ['наверно']
# [('еда', 1.0000001192092896)]
# ['еда']
# [('его', 1.0)]
# ['его']
# [('отправиться', 1.0000001192092896)]
# ['отправиться']
# [('поехать', 1.0000001192092896)]
# ['поехать']
# [('картошка', 0.9999999403953552)]
# ['картошка']
# [('цветки', 1.0000001192092896)]
# ['цветки']
# [('кольцо', 1.0000001192092896)]
# ['кольцо']
# [('кино', 1.0000001192092896)]
# ['кино']
# [('лоскут', 1.0000001192092896)]
# ['лоскут']
# [('клиент', 1.0)]
# ['клиент']
# [('колено', 1.0000001192092896)]
# ['колено']
# [('колодец', 1.0)]
# ['колодец']
# [('запятая', 1.0)]
# ['запятая']
# [('коммунизм', 1.0)]
# ['коммунизм']
# [('конфликт', 1.0)]
# ['конфликт']
# [('копейка', 1.0)]
# ['копейка']
# [('рубеж', 1.0)]
# ['рубеж']
# [('корень', 1.0000001192092896)]
# ['корень']
# [('страна', 1.0000001192092896)]
# ['страна']
# [('страны', 1.0000001192092896)]
# ['страны']
# [('пулемет', 0.9999999403953552)]
# ['пулемет']
# [('пуля', 1.0000001192092896)]
# ['пуля']
# [('лаборатория', 1.0)]
# ['лаборатория']
# [('скамейка', 1.0000001192092896)]
# ['скамейка']
# [('баня', 1.0)]
# ['баня']
# [('ломать', 1.0)]
# ['ломать']
# [('июль', 1.0000001192092896)]
# ['июль']
# [('лед', 0.9999998807907104)]
# ['лед']
# [('доктор', 0.9999999403953552)]
# ['доктор']
# [('лететь', 0.9999998807907104)]
# ['лететь']
# [('лифт', 1.0000001192092896)]
# ['лифт']
# [('ледяной', 0.9999999403953552)]
# ['ледяной']
# [('ложиться', 1.0)]
# ['ложиться']
# [('малыш', 1.0)]
# ['малыш']
# [('массовый', 1.0)]
# ['массовый']
# [('мне', 1.0)]
# ['мне']
# [('металлический', 1.0)]
# ['металлический']
# [('миг', 1.0)]
# ['миг']
# [('меняться', 0.9999999403953552)]
# ['меняться']
# [('городок', 1.0)]
# ['городок']
# [('мост', 0.9999999403953552)]
# ['мост']
# [('мешок', 1.0)]
# ['мешок']
# [('молчание', 1.0)]
# ['молчание']
# [('молодежь', 1.0)]
# ['молодежь']
# [('жутко', 1.0)]
# ['жутко']
# [('мертвец', 1.0)]
# ['мертвец']
# [('музыка', 1.0000001192092896)]
# ['музыка']
# [('музыкант', 0.9999999403953552)]
# ['музыкант']
# [('приближаться', 1.0000001192092896)]
# ['приближаться']
# [('надоесть', 1.0000001192092896)]
# ['надоесть']
# [('весна', 1.0000001192092896)]
# ['весна']
# [('вокруг', 1.0)]
# ['вокруг']
# [('напротив', 0.9999999403953552)]
# ['напротив']
# [('напомнить', 1.0)]
# ['напомнить']
# [('навсегда', 1.0)]
# ['навсегда']
# [('тираж', 0.9999999403953552)]
# ['тираж']
# [('налить', 1.0)]
# ['налить']
# [('намерение', 1.0000001192092896)]
# ['намерение']
# [('например', 1.0)]
# ['например']
# [('совещание', 1.0)]
# ['совещание']
# [('настроение', 1.0000001192092896)]
# ['настроение']
# [('нация', 1.0000001192092896)]
# ['нация']
# [('наличие', 0.9999999403953552)]
# ['наличие']
# [('невидимый', 1.0)]
# ['невидимый']
# [('тотчас', 1.0)]
# ['тотчас']
# [('негромко', 1.0)]
# ['негромко']
# [('непонятный', 0.9999998807907104)]
# ['непонятный']
# [('невозможно', 1.0)]
# ['невозможно']
# [('неприятность', 1.0000001192092896)]
# ['неприятность']
# [('дебри', 1.0)]
# ['дебри']
# [('ею', 1.0)]
# ['ею']
# [('якобы', 0.9999999403953552)]
# ['якобы']
# [('нигде', 1.0000001192092896)]
# ['нигде']
# [('чем', 1.0000001192092896)]
# ['чем']
# [('ничто', 0.9999998807907104)]
# ['ничто']
# [('него', 1.0)]
# ['него']
# [('оазис', 1.0000001192092896)]
# ['оазис']
# [('обещать', 0.9999999403953552)]
# ['обещать']
# [('ограничение', 1.0000001192092896)]
# ['ограничение']
# [('обида', 1.0000001192092896)]
# ['обида']
# [('возмущение', 1.0000001192092896)]
# ['возмущение']
# [('осмотреть', 1.0)]
# ['осмотреть']
# [('жениться', 1.0)]
# ['жениться']
# [('организовать', 1.0000001192092896)]
# ['организовать']
# [('основа', 0.9999999403953552)]
# ['основа']
# [('основание', 1.0)]
# ['основание']
# [('особенность', 1.0)]
# ['особенность']
# [('особо', 1.0)]
# ['особо']
# [('последний', 1.0000001192092896)]
# ['последний']
# [('окружить', 1.0)]
# ['окружить']
# [('полезть', 1.0)]
# ['полезть']
# [('дворец', 1.0000001192092896)]
# ['дворец']
# [('партийный', 1.0000001192092896)]
# ['партийный']
# [('пасть', 1.0)]
# ['пасть']
# [('наверное', 1.0)]
# ['наверное']
# [('пенсия', 1.0)]
# ['пенсия']
# [('проверка', 0.9999999403953552)]
# ['проверка']
# [('двинуться', 1.0)]
# ['двинуться']
# [('победа', 1.0000001192092896)]
# ['победа']
# [('парикмахерская', 1.0000001192092896)]
# ['парикмахерская']
# [('первый', 1.0)]
# ['первый']
# [('полчаса', 1.0000001192092896)]
# ['полчаса']
# [('подбородок', 1.0)]
# ['подбородок']
# [('пиджак', 1.0)]
# ['пиджак']
# [('подозревать', 1.0)]
# ['подозревать']
# [('подпись', 1.0)]
# ['подпись']
# [('платить', 1.0)]
# ['платить']
# [('бутылка', 1.0)]
# ['бутылка']
# [('свидание', 1.0)]
# ['свидание']
# [('побывать', 0.9999999403953552)]
# ['побывать']
# [('возвращение', 1.000000238418579)]
# ['возвращение']
# [('мимо', 0.9999999403953552)]
# ['мимо']
# [('ползти', 1.0000001192092896)]
# ['ползти']
# [('медленно', 0.9999998807907104)]
# ['медленно']
# [('подарить', 1.0000001192092896)]
# ['подарить']
# [('позвать', 0.9999999403953552)]
# ['позвать']
# [('дыхание', 1.0)]
# ['дыхание']
# [('нравиться', 1.0)]
# ['нравиться']
# [('во-вторых', 1.0)]
# ['во-вторых']
# [('благодарность', 1.0000001192092896)]
# ['благодарность']
# [('костер', 1.0)]
# ['костер']
# [('поездка', 0.9999999403953552)]
# ['поездка']
# [('покинуть', 1.0)]
# ['покинуть']
# [('умирать', 0.9999999403953552)]
# ['умирать']
# [('помощник', 0.9999998807907104)]
# ['помощник']
# [('поправить', 1.0)]
# ['поправить']
# [('сравнительно', 0.9999999403953552)]
# ['сравнительно']
# [('поражение', 1.0000001192092896)]
# ['поражение']
# [('раненый', 1.0)]
# ['раненый']
# [('сравнение', 0.9999998807907104)]
# ['сравнение']
# [('порог', 0.9999998807907104)]
# ['порог']
# [('постараться', 1.0)]
# ['постараться']
# [('фигура', 1.0)]
# ['фигура']
# [('постоянно', 1.0)]
# ['постоянно']
# [('постепенно', 0.9999998807907104)]
# ['постепенно']
# [('поиск', 1.0)]
# ['поиск']
# [('правильный', 1.0000001192092896)]
# ['правильный']
# [('борт', 1.0)]
# ['борт']
# [('прибыть', 1.0)]
# ['прибыть']
# [('приготовить', 1.0)]
# ['приготовить']
# [('заходить', 1.0000001192092896)]
# ['заходить']
# [('предполагать', 0.9999999403953552)]
# ['предполагать']
# [('прислушиваться', 1.0000001192092896)]
# ['прислушиваться']
# [('аппарат', 1.0)]
# ['аппарат']
# [('скрывать', 1.0)]
# ['скрывать']
# [('проект', 1.0000001192092896)]
# ['проект']
# [('об', 1.0000001192092896)]
# ['об']
# [('однако', 1.0)]
# ['однако']
# [('направить', 1.0)]
# ['направить']
# [('пустыня', 0.9999999403953552)]
# ['пустыня']
# [('внезапно', 1.0)]
# ['внезапно']
# [('рыбак', 0.9999998807907104)]
# ['рыбак']
# [('ровный', 1.0)]
# ['ровный']
# [('уровни', 0.9999999403953552)]
# ['уровни']
# [('резкий', 0.9999998807907104)]
# ['резкий']
# [('разница', 1.0)]
# ['разница']
# [('реки', 1.0)]
# ['реки']
# [('речка', 1.0)]
# ['речка']
# [('разглядывать', 0.9999999403953552)]
# ['разглядывать']
# [('полотенце', 1.0000001192092896)]
# ['полотенце']
# [('спасатель', 1.0)]
# ['спасатель']
# [('спасать', 1.0000001192092896)]
# ['спасать']
# [('свидетель', 1.0)]
# ['свидетель']
# [('рассвет', 1.0)]
# ['рассвет']
# [('свет', 0.9999999403953552)]
# ['свет']
# [('поселок', 1.0000001192092896)]
# ['поселок']
# [('середина', 1.0)]
# ['середина']
# [('август', 1.0)]
# ['август']
# [('сёстры', 1.0)]
# ['сёстры']
# [('сидя', 0.9999999403953552)]
# ['сидя']
# [('сырой', 1.0000001192092896)]
# ['сырой']
# [('семьи', 1.0)]
# ['семьи']
# [('семьсот', 0.9999999403953552)]
# ['семьсот']
# [('скромный', 1.0)]
# ['скромный']
# [('служебный', 1.0)]
# ['служебный']
# [('послушать', 1.0000001192092896)]
# ['послушать']
# [('мусор', 0.9999998807907104)]
# ['мусор']
# [('жареный', 1.0)]
# ['жареный']
# [('себе', 1.0)]
# ['себе']
# [('копье', 0.9999998807907104)]
# ['копье']
# [('спрашивать', 1.0000001192092896)]
# ['спрашивать']
# [('воспоминание', 0.9999999403953552)]
# ['воспоминание']
# [('справедливость', 1.0000001192092896)]
# ['справедливость']
# [('серебряный', 1.0)]
# ['серебряный']
# [('курс', 1.0)]
# ['курс']
# [('старинный', 1.0)]
# ['старинный']
# [('создавать', 0.9999998807907104)]
# ['создавать']
# [('бедро', 1.0000001192092896)]
# ['бедро']
# [('страница', 0.9999999403953552)]
# ['страница']
# [('сотня', 0.9999998807907104)]
# ['сотня']
# [('стоять', 0.9999999403953552)]
# ['стоять']
# [('лента', 1.0)]
# ['лента']
# [('стучать', 1.0)]
# ['стучать']
# [('степень', 1.0000001192092896)]
# ['степень']
# [('строгий', 0.9999999403953552)]
# ['строгий']
# [('суровый', 1.0)]
# ['суровый']
# [('судья', 1.0)]
# ['судья']
# [('печальный', 0.9999998807907104)]
# ['печальный']
# [('сплошной', 1.0)]
# ['сплошной']
# [('ступенька', 1.0000001192092896)]
# ['ступенька']
# [('телефонный', 1.0)]
# ['телефонный']
# [('территория', 0.9999998807907104)]
# ['территория']
# [('срочно', 0.9999999403953552)]
# ['срочно']
# [('срок', 1.0)]
# ['срок']
# [('тыл', 1.0)]
# ['тыл']
# [('тогдашняя', 1.0000001192092896)]
# ['тогдашняя']
# [('тогда', 1.0)]
# ['тогда']
# [('потому', 1.0)]
# ['потому']
# [('пытки', 0.9999998807907104)]
# ['пытки']
# [('май', 0.9999998807907104)]
# ['май']
# [('травы', 0.9999998807907104)]
# ['травы']
# [('традиция', 0.9999999403953552)]
# ['традиция']
# [('случиться', 1.0)]
# ['случиться']
# [('длится', 1.0000001192092896)]
# ['длится']
# [('длительный', 1.0)]
# ['длительный']
# [('продолжаться', 1.0)]
# ['продолжаться']
# [('держать', 1.0)]
# ['держать']
# [('трудовой', 1.0)]
# ['трудовой']
# [('гроб', 1.0)]
# ['гроб']
# [('гроб', 1.0)]
# ['гроб']
# [('здесь', 1.0000001192092896)]
# ['здесь']
# [('сюда', 0.9999999403953552)]
# ['сюда']
# [('тащить', 1.0)]
# ['тащить']
# [('наряд', 0.9999998807907104)]
# ['наряд']
# [('вечер', 1.0)]
# ['вечер']
# [('украсть', 1.0)]
# ['украсть']
# [('университет', 0.9999999403953552)]
# ['университет']
# [('успех', 1.0000001192092896)]
# ['успех']
# [('профессионально', 1.0)]
# ['профессионально']
# [('фильм', 1.0000001192092896)]
# ['фильм']
# [('функция', 1.0)]
# ['функция']
# [('волна', 1.0)]
# ['волна']
# [('волнение', 1.0000001192092896)]
# ['волнение']
# [('хвост', 1.0)]
# ['хвост']
# [('парни', 1.0)]
# ['парни']
# [('облако', 1.0)]
# ['облако']
# [('крест', 1.0000001192092896)]
# ['крест']
# [('сей', 1.0000001192092896)]
# ['сей']
# [('церковь', 1.0)]
# ['церковь']
# [('гражданский', 1.0)]
# ['гражданский']
# [('фигура', 1.0)]
# ['фигура']
# [('интересоваться', 1.0000001192092896)]
# ['интересоваться']
# [('сахар', 1.0)]
# ['сахар']
# [('ждать', 1.0)]
# ['ждать']
# [('подождать', 1.0)]
# ['подождать']
# [('чей', 0.9999998807907104)]
# ['чей']
# [('номер', 1.0)]
# ['номер']
# [('прочесть', 0.9999999403953552)]
# ['прочесть']
# [('читать', 0.9999999403953552)]
# ['читать']
# [('сапоги', 1.0)]
# ['сапоги']
# [('мужчина', 1.0)]
# ['мужчина']
# [('иностранец', 1.0)]
# ['иностранец']
# [('слышать', 1.0)]
# ['слышать']
# [('слышаться', 1.0)]
# ['слышаться']
# [('ветчина', 0.9999999403953552)]
# ['ветчина']
# [('шоссе', 1.0)]
# ['шоссе']
# [('шестой', 0.9999999403953552)]
# ['шестой']
# [('щёки', 1.0)]
# ['щёки']
# [('тому', 1.0)]
# ['тому']
# [('кой', 1.0)]
# ['кой']
# [('качество', 1.0000001192092896)]
# ['качество']
# [('чего', 0.9999998807907104)]
# ['чего']

# %%
precision_top1 = precision(uk_ru_test, mapping.predict(X_test), 1)
precision_top5 = precision(uk_ru_test, mapping.predict(X_test), 5)

assert precision_top1 >= 0.635
assert precision_top5 >= 0.81 # TODO: was 0.813 in course notebook, mine in a bit smaller

# %% [markdown]
# ## Making it better (orthogonal Procrustean problem)

# %% [markdown]
# It can be shown (see original paper) that a self-consistent linear mapping between semantic spaces should be orthogonal.
# We can restrict transform $W$ to be orthogonal. Then we will solve next problem:
#
# $$W^*= \arg\min_W ||WX - Y||_F \text{, where: } W^TW = I$$
#
# $$I \text{- identity matrix}$$
#
# Instead of making yet another regression problem we can find optimal orthogonal transformation using singular value decomposition. It turns out that optimal transformation $W^*$ can be expressed via SVD components:
# $$X^TY=U\Sigma V^T\text{, singular value decompostion}$$
# $$W^*=UV^T$$

# %%
from sklearn.utils.extmath import randomized_svd

def learn_transform(X_train, Y_train):
    """ 
    :returns: W* : float matrix[emb_dim x emb_dim] as defined in formulae above
    """
    # YOU CODE HERE
    U, Sigma, VT = randomized_svd(np.matmul(X_train.T, Y_train), n_components=15, n_iter=5, random_state=None)
    
    W = np.matmul(U, VT)
    
    print(W.shape)
    return W

# %%
W = learn_transform(X_train, Y_train)
# Out:
# (300, 300)

# %%
ru_emb.most_similar([np.matmul(uk_emb["серпень"], W)])
# Out:
# [('этот', 0.6490505933761597),
#  ('день', 0.637031078338623),
#  ('год', 0.6260989308357239),
#  ('последний', 0.6247546076774597),
#  ('первый', 0.6213812232017517),
#  ('третий', 0.6039137244224548),
#  ('осенний', 0.6014647483825684),
#  ('воскресный', 0.5994681715965271),
#  ('пятый', 0.5935832262039185),
#  ('вечер', 0.5933817625045776)]

# %%
precision1 = precision(uk_ru_test, np.matmul(X_test, W))
print(precision1)

assert precision1 >= 0.653
assert precision(uk_ru_test, np.matmul(X_test, W), 5) >= 0.824
# Out:
# 0.056847545219638244
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 print(precision(uk_ru_test, np.matmul(X_test, W)))
# ----> 2 assert precision(uk_ru_test, np.matmul(X_test, W)) >= 0.653
#       3 assert precision(uk_ru_test, np.matmul(X_test, W), 5) >= 0.824
#
# AssertionError:

# %% [markdown]
# ## UK-RU Translator

# %% [markdown]
# Now we are ready to make simple word-based translator: for each word in source language in shared embedding space we find the nearest in target language.

# %%
with open("fairy_tale.txt", "r") as inpf:
    uk_sentences = [line.rstrip().lower() for line in inpf]

# %%
def translate(sentence):
    """
    :args:
        sentence - sentence in Ukrainian (str)
    :returns:
        translation - sentence in Russian (str)

    * find ukrainian embedding for each word in sentence
    * transform ukrainian embedding vector
    * find nearest russian word and replace
    """
    # YOUR CODE HERE

# %%
assert translate(".") == "."
assert translate("1 , 3") == "1 , 3"
assert translate("кіт зловив мишу") == "кот поймал мышку"

# %%
for sentence in uk_sentences:
    print("src: {}\ndst: {}\n".format(sentence, translate(sentence)))

# %% [markdown]
# Not so bad, right? We can easily improve translation using language model and not one but several nearest neighbours in shared embedding space. But next time.

# %% [markdown]
# ## Would you like to learn more?
#
# ### Articles:
# * [Exploiting Similarities among Languages for Machine Translation](https://arxiv.org/pdf/1309.4168)  - entry point for multilingual embedding studies by Tomas Mikolov (the author of W2V)
# * [Offline bilingual word vectors, orthogonal transformations and the inverted softmax](https://arxiv.org/pdf/1702.03859) - orthogonal transform for unsupervised MT
# * [Word Translation Without Parallel Data](https://arxiv.org/pdf/1710.04087)
# * [Loss in Translation: Learning Bilingual Word Mapping with a Retrieval Criterion](https://arxiv.org/pdf/1804.07745)
# * [Unsupervised Alignment of Embeddings with Wasserstein Procrustes](https://arxiv.org/pdf/1805.11222)
#
# ### Repos (with ready-to-use multilingual embeddings):
# * https://github.com/facebookresearch/MUSE
#
# * https://github.com/Babylonpartners/fastText_multilingual -
