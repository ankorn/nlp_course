# %% [markdown]
# > ## tokenization
#
# ## metrics
# recall, acc
#
# > ## embeddings
#
# ## chain rule for derivatives
#
# ## chain rule for probabilities
#
# ## cross-entropy loss
#
# ## cnn for next
#
# ## rnn for text
