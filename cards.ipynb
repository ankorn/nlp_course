# %% [markdown]
# > ## tokenization
#
# ## metrics
# recall, acc
#
# ## embeddings
# сейчас представления учит енкодер трансформера?
#
# ## chain rule for derivatives
#
# ## chain rule for probabilities
