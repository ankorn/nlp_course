# %% [markdown]
# >> #### preprocessing
#
# >> #### embeddings
#
# >> #### text classification
#
# >> #### rnn for text classification
#
# >> #### language modelling
#
# >> #### seq2seq basics
#
# >> #### attention
#
# >> #### transfromer
#
# >> #### transfer learning
#
# >> #### llms
#
# >> #### peft
#
# >> #### gpt learning process
#
# >> #### efficiency
#
# >> #### retrieval, agents
#
# >> #### norms
#
# >> #### chain rule for derivatives
#
# >> #### cross-entropy loss
#
# >> #### practical methodology, performance metrics
#
# >> #### backprop, sgd, adam
#
# >> #### regularization
#
# ## bias, variance
#
# подробнее про современные отличия трансофрмера: гейтед ффн, ембеддинги
