# %% [markdown]
# >> #### tokenization
#
# >> #### embeddings
#
# >> #### text classification
#
# >> #### rnn for text classification
#
# >> #### language modelling
#
# >> #### seq2seq basics
#
# >> #### attention
#
# >> #### transfromer
#
# >> #### transfer learning
#
# >> #### llms
#
# >> #### peft
#
# >> #### gpt learning process
#
# >> #### efficiency
#
# >> #### norms
#
# >> #### chain rule for derivatives
#
# >> #### cross-entropy loss
#
# >> #### practical methodology, performance metrics
#
# >> #### backprop, sgd, adam(main for transformers)(8.3)
#
# ## regularization
#
# ## bias, variance
#
# подробнее про современные отличия трансофрмера: гейтед ффн, ембеддинги
