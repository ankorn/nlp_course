# %% [markdown]
# >> #### tokenization
#
#
# >> #### embeddings
#
# >> #### text classification
#
# >> #### rnn for text classification
#
# >> #### language modelling
#
# >> #### seq2seq basics
#
# >> #### attention
#
# >> #### transfromer
#
# >> #### transfer learning
#
# >> #### llms
#
# >> #### peft
#
# >> #### gpt learning process
#
# >> #### efficiency
#
# ## benchmarks: glue, superglue
#
# ## agents, convention from open ai
# to retrieval card?
#
# >>
#
# >> #### norms
#
# ## chain rule for derivatives
# в главе по бекпропу
#
# ## chain rule for probabilities
#
# ## cross-entropy loss
# https://lena-voita.github.io/nlp_course/language_modeling.html#neural_lms_training
# log
#
# ## metrics
# recall, acc
#
# ## ...Goodfellow
