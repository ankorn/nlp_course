# %% [markdown]
# >> #### tokenization
#
# ## metrics
# recall, acc
#
# >> #### embeddings
#
# ## chain rule for derivatives
#
# ## chain rule for probabilities
#
# ## cross-entropy loss
# https://lena-voita.github.io/nlp_course/language_modeling.html#neural_lms_training
# log
#
# >> #### text classification
#
# >> #### rnn for text classification
#
# >> #### language modelling
#
# >> #### seq2seq basics
#
# >> #### attention
#
# >> #### transfromer
#
# >> #### transfer learning
#
# >> #### llms
#
# ## norms
#
# ## benchmarks: glue, superglue
#
# ## adapters: https://lena-voita.github.io/nlp_course/transfer_learning.html#adapters
# maybe as a part of peft?
#
# ## peft
#
# ## ...Goodfellow
