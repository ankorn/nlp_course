# %% [markdown]
# >> #### tokenization
#
#
# >> #### embeddings
#
# >> #### text classification
#
# >> #### rnn for text classification
#
# >> #### language modelling
#
# >> #### seq2seq basics
#
# >> #### attention
#
# >> #### transfromer
#
# >> #### transfer learning
#
# >> #### llms
#
# >> #### peft
#
# >> #### gpt learning process
#
# >> #### efficiency
#
# >>
#
# >> #### norms
#
# ## chain rule for derivatives
# в главе по бекпропу
#
# ## cross-entropy loss
# https://lena-voita.github.io/nlp_course/language_modeling.html#neural_lms_training
#
# ## performance metrics
# acc, precision, recall, f1-score
#
# ## backprop(8.3)
#
# ## regularization
#
# ## sgd, adam(main for transformers)
#
# ## bias, variance
#
# ## practical methodology
