# %% [markdown]
# ### Homework 5: Question search engine
#
# Remeber week01 where you used GloVe embeddings to find related questions? That was.. cute, but far from state of the art. It's time to really solve this task using context-aware embeddings.
#
# __Warning:__ this task assumes you have seen `seminar.ipynb`!

# %%
# %pip install --upgrade transformers datasets accelerate tqdm protobuf sentencepiece evaluate
import torch
import torch.nn as nn
import torch.nn.functional as F
import transformers
import datasets
from tqdm import tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (4.48.0)
# Requirement already satisfied: datasets in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (3.2.0)
# Requirement already satisfied: accelerate in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: tqdm in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (4.67.1)
# Requirement already satisfied: protobuf in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (5.29.3)
# Requirement already satisfied: sentencepiece in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (0.2.0)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: filelock in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from datasets) (3.11.11)
# Requirement already satisfied: psutil in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: torch>=1.10.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from accelerate) (2.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: sympy in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Load data and model

# %%
qqp = datasets.load_dataset('SetFit/qqp')
print('\n')
print("Sample[0]:", qqp['train'][0])
print("Sample[3]:", qqp['train'][3])
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Sample[0]: {'text1': 'How is the life of a math student? Could you describe your own experiences?', 'text2': 'Which level of prepration is enough for the exam jlpt5?', 'label': 0, 'idx': 0, 'label_text': 'not duplicate'}
# Sample[3]: {'text1': 'What can one do after MBBS?', 'text2': 'What do i do after my MBBS ?', 'label': 1, 'idx': 3, 'label_text': 'duplicate'}

# %%
model_name = "gchhablani/bert-base-cased-finetuned-qqp"
tokenizer = transformers.AutoTokenizer.from_pretrained(model_name)
model = transformers.AutoModelForSequenceClassification.from_pretrained(model_name)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /Users/ant.korneev/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Tokenize the data

# %%
MAX_LENGTH = 128
def preprocess_function(examples):
    result = tokenizer(
        examples['text1'], examples['text2'],
        padding='max_length', max_length=MAX_LENGTH, truncation=True
    )
    result['label'] = examples['label']
    return result

qqp_preprocessed = qqp.map(preprocess_function, batched=True)
# Out:
# Map: 100%|██████████| 363846/363846 [00:14<00:00, 24650.16 examples/s]
# Map: 100%|██████████| 40430/40430 [00:01<00:00, 24620.94 examples/s]
# Map: 100%|██████████| 390965/390965 [00:15<00:00, 24903.69 examples/s]

# %%
print(repr(qqp_preprocessed['train'][0]['input_ids'])[:100], "...")
# Out:
# [101, 1731, 1110, 1103, 1297, 1104, 170, 12523, 2377, 136, 7426, 1128, 5594, 1240, 1319, 5758, 136,  ...

# %% [markdown]
# ### Task 1: evaluation (1 point)
#
# We randomly chose a model trained on QQP - but is it any good?
#
# One way to measure this is with validation accuracy - which is what you will implement next.
#
# Here's the interface to help you do that:

# %%
batch_size = 5 # 1

val_set = qqp_preprocessed['validation']
val_loader = torch.utils.data.DataLoader(
    val_set,
    batch_size=batch_size,
    shuffle=False,
    collate_fn=transformers.default_data_collator,
    # num_workers=2
)
print(val_set['label'][0], val_set['label_text'][0], val_set['text1'][0], val_set['text2'][0])
print(val_set['label'][2], val_set['label_text'][2], val_set['text1'][2], val_set['text2'][2])
# Out:
# 0 not duplicate Why are African-Americans so beautiful? Why are hispanics so beautiful?
# 1 duplicate Is there a reason why we should travel alone? What are some reasons to travel alone?

# %% [markdown]
# __Your task__ is to measure the validation accuracy of your model.
# Doing so naively may take several hours. Please make sure you use the following optimizations:
#
# - run the model on GPU with no_grad
# - using batch size larger than 1
# - use optimize data loader with num_workers > 1
# - (optional) use [mixed precision](https://pytorch.org/docs/stable/notes/amp_examples.html)

# %%
samples_count = 0
successfull_preds_count = 0

model.eval()

for batch in tqdm(val_loader):
    with torch.no_grad():
        predicted = model(
            input_ids=batch['input_ids'],
            attention_mask=batch['attention_mask'],
            token_type_ids=batch['token_type_ids']
        )
        
    probs = torch.softmax(predicted.logits, dim=1)
    
    batch_successfull_preds_count = 0
    for i, sample_probs in enumerate(probs):
        y = batch['labels'][i]
        if sample_probs[y] >= 0.5:
            batch_successfull_preds_count += 1
            
    successfull_preds_count += batch_successfull_preds_count
    samples_count += batch['labels'].size(0)
    
accuracy = successfull_preds_count / samples_count
accuracy
# Out:
# 100%|██████████| 8086/8086 [36:22<00:00,  3.70it/s]
# 0.9083848627256987

# %%
assert 0.9 < accuracy < 0.91

# %% [markdown]
# ### Task 2: train the model (4 points)
#
# For this task, you have two options:
#
# __Option A:__ fine-tune your own model. You are free to choose any model __except for the original BERT.__ We recommend [DeBERTa-v3](https://huggingface.co/microsoft/deberta-v3-base). Better yet, choose the best model based on public benchmarks (e.g. [GLUE](https://gluebenchmark.com/)).
#
# You can write the training code manually or use transformers.Trainer (see [this example](https://github.com/huggingface/transformers/blob/main/examples/pytorch/text-classification)). Please make sure that your model's accuracy is at least __comparable__ with the above example for BERT.
#
#
# __Option B:__ compare at least 3 pre-finetuned models (in addition to the above BERT model). For each model, report (1) its accuracy, (2) its speed, measured in samples per second in your hardware setup and (3) its size in megabytes. Please take care to compare models in equal setting, e.g. same CPU / GPU. Compile your results into a table and write a short (~half-page on top of a table) report, summarizing your findings.

# %%
model_name = "microsoft/deberta-v3-base"
tokenizer = transformers.AutoTokenizer.from_pretrained(model_name, use_fast = False)
model = transformers.AutoModelForSequenceClassification.from_pretrained(model_name)
# Out:
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
MAX_LENGTH = 128
def preprocess_function(examples):
    result = tokenizer(
        examples['text1'],
        examples['text2'],
        padding='max_length',
        max_length=MAX_LENGTH,
        truncation=True
    )
    result['label'] = examples['label']
    return result

qqp_preprocessed = qqp.map(preprocess_function, batched=True)

qqp_preprocessed
# Out:
# Map:   0%|          | 1000/363846 [00:00<00:39, 9119.58 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   1%|          | 3000/363846 [00:00<00:39, 9196.81 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   2%|▏         | 9000/363846 [00:01<00:47, 7405.06 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   4%|▍         | 14000/363846 [00:01<00:40, 8544.31 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   4%|▍         | 16000/363846 [00:01<00:38, 8919.47 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   8%|▊         | 28000/363846 [00:03<00:36, 9275.42 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   9%|▊         | 31000/363846 [00:03<00:36, 9213.30 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  10%|▉         | 36000/363846 [00:04<00:35, 9263.90 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  12%|█▏        | 43000/363846 [00:04<00:41, 7653.76 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  14%|█▎        | 50000/363846 [00:05<00:34, 9030.83 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  15%|█▍        | 53000/363846 [00:06<00:34, 9081.98 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  17%|█▋        | 62000/363846 [00:07<00:33, 9031.59 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  17%|█▋        | 63000/363846 [00:07<00:33, 8944.43 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  18%|█▊        | 65000/363846 [00:07<00:32, 9062.92 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  19%|█▊        | 68000/363846 [00:07<00:33, 8925.50 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  20%|█▉        | 71000/363846 [00:08<00:32, 8916.02 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  22%|██▏       | 79000/363846 [00:08<00:36, 7827.51 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  23%|██▎       | 84000/363846 [00:09<00:31, 8957.53 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  25%|██▍       | 90000/363846 [00:10<00:31, 8690.26 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  28%|██▊       | 102000/363846 [00:11<00:28, 9277.10 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  29%|██▉       | 105000/363846 [00:11<00:27, 9293.06 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  32%|███▏      | 115000/363846 [00:13<00:30, 8212.05 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  33%|███▎      | 120000/363846 [00:13<00:27, 8902.96 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  34%|███▍      | 124000/363846 [00:14<00:26, 9037.07 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  34%|███▍      | 125000/363846 [00:14<00:26, 9056.31 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  35%|███▍      | 127000/363846 [00:14<00:26, 9058.07 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  35%|███▌      | 128000/363846 [00:14<00:26, 8968.67 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  36%|███▌      | 130000/363846 [00:14<00:25, 8996.19 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  37%|███▋      | 133000/363846 [00:15<00:25, 8930.52 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  37%|███▋      | 135000/363846 [00:15<00:25, 8815.81 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  37%|███▋      | 136000/363846 [00:15<00:25, 8855.64 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  38%|███▊      | 138000/363846 [00:15<00:29, 7677.60 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  38%|███▊      | 139000/363846 [00:15<00:28, 7956.77 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  38%|███▊      | 140000/363846 [00:15<00:27, 8237.12 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  41%|████      | 150000/363846 [00:17<00:23, 9121.28 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  42%|████▏     | 153000/363846 [00:17<00:24, 8514.32 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:
examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  60%|█████▉    | 233000/390965 [00:27<00:18, 8572.41 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  61%|██████    | 237000/390965 [00:27<00:18, 8353.54 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  63%|██████▎   | 246000/390965 [00:28<00:18, 8047.54 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  65%|██████▍   | 253000/390965 [00:29<00:15, 8925.64 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  66%|██████▌   | 258000/390965 [00:29<00:14, 8937.87 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  68%|██████▊   | 265000/390965 [00:30<00:14, 8756.22 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  69%|██████▊   | 268000/390965 [00:31<00:13, 8896.61 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  70%|██████▉   | 272000/390965 [00:31<00:13, 8923.94 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  74%|███████▍  | 291000/390965 [00:33<00:11, 9010.53 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  76%|███████▌  | 297000/390965 [00:34<00:10, 9044.41 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  76%|███████▌  | 298000/390965 [00:34<00:10, 9052.95 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  78%|███████▊  | 304000/390965 [00:35<00:09, 8989.89 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  78%|███████▊  | 305000/390965 [00:35<00:09, 8937.19 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  78%|███████▊  | 306000/390965 [00:35<00:09, 8955.11 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  81%|████████  | 317000/390965 [00:36<00:08, 8402.31 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  88%|████████▊ | 344000/390965 [00:39<00:05, 8734.49 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  95%|█████████▍| 370000/390965 [00:42<00:02, 8747.74 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  96%|█████████▋| 377000/390965 [00:43<00:01, 8635.58 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  97%|█████████▋| 380000/390965 [00:44<00:01, 8827.85 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  98%|█████████▊| 384000/390965 [00:44<00:00, 9000.46 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map: 100%|██████████| 390965/390965 [00:45<00:00, 8615.95 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text1', 'text2', 'label', 'idx', 'label_text', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 363846
#     })
#     validation: Dataset({
#         features: ['text1', 'text2', 'label', 'idx', 'label_text', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 40430
#     })
#     test: Dataset({
#         features: ['text1', 'text2', 'label', 'idx', 'label_text', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 390965
#     })
# })

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(output_dir="deberta_train", eval_strategy="epoch")

# %%
import evaluate

metric = evaluate.load("accuracy")

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = torch.softmax(logits, dim=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=qqp_preprocessed['train'],
    eval_dataset=qqp_preprocessed['validation'],
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2408' max='136443' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  2408/136443 40:50 < 37:55:21, 0.98 it/s, Epoch 0.05/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 trainer.train()
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/trainer.py:2171, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2169         hf_hub_utils.enable_progress_bars()
#    2170 else:
# -> 2171     return inner_training_loop(
#    2172         args=args,
#    2173         resume_from_checkpoint=resume_from_checkpoint,
#    2174         trial=trial,
#    2175         ignore_keys_for_eval=ignore_keys_for_eval,
#    2176     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/trainer.py:2584, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2580         grad_norm = _grad_norm
#    2582 self.control = self.callback_handler.on_pre_optimizer_step(args, self.state, self.control)
# -> 2584 self.optimizer.step()
#    2586 self.control = self.callback_handler.on_optimizer_step(args, self.state, self.control)
#    2588 optimizer_was_run = not self.accelerator.optimizer_step_was_skipped
#
# File ~/Library/Python/3.9/lib/python/site-packages/accelerate/optimizer.py:156, in AcceleratedOptimizer.step(self, closure)
#     153     xm.all_reduce("sum", gradients, scale=1.0 / xm.xrt_world_size())
#     154     self.gradient_state.is_xla_gradients_synced = True
# --> 156 if is_lomo_available():
#     157     #  `step` should be a no-op for LOMO optimizers.
#     158     if isinstance(self.optimizer, (Lomo, AdaLomo)):
#     159         return
#
# File ~/Library/Python/3.9/lib/python/site-packages/accelerate/utils/imports.py:109, in is_lomo_available()
#     108 def is_lomo_available():
# --> 109     return _is_package_available("lomo_optim")
#
# File ~/Library/Python/3.9/lib/python/site-packages/accelerate/utils/imports.py:51, in _is_package_available(pkg_name, metadata_name)
#      49 def _is_package_available(pkg_name, metadata_name=None):
#      50     # Check we're not importing a "pkg_name" directory somewhere but the actual library by trying to grab the version
# ---> 51     package_exists = importlib.util.find_spec(pkg_name) is not None
#      52     if package_exists:
#      53         try:
#      54             # Some libraries have different names in the metadata
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/util.py:103, in find_spec(name, package)
#     101     else:
#     102         parent_path = None
# --> 103     return _find_spec(fullname, parent_path)
#     104 else:
#     105     module = sys.modules[fullname]
#
# File <frozen importlib._bootstrap>:925, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1414, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1383, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1347, in _path_importer_cache(cls, path)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Task 3: try the full pipeline (1 point)
#
# Finally, it is time to use your model to find duplicate questions.
# Please implement a function that takes a question and finds top-5 potential duplicates in the training set. For now, it is fine if your function is slow, as long as it yields correct results.
#
# Showcase how your function works with at least 5 examples.

# %% [markdown]
# __Bonus:__ for bonus points, try to find a way to run the function faster than just passing over all questions in a loop. For isntance, you can form a short-list of potential candidates using a cheaper method, and then run your tranformer on that short list. If you opted for this solution, please keep both the original implementation and the optimized one - and explain briefly what is the difference there.
